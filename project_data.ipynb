# %%
import pandas as pd

df = pd.read_json('Movies_and_TV_5.json', lines=True)
df = df.drop(columns=['verified','reviewerID','reviewTime','vote','unixReviewTime','image','asin'])
df
# Out:
#       overall                         style            reviewerName  \
# 0           5      {'Format:': ' VHS Tape'}                   Terri
# 1           5      {'Format:': ' VHS Tape'}  Melissa D. Abercrombie
# 2           5           {'Format:': ' DVD'}        Anthony Thompson
# 3           5           {'Format:': ' DVD'}                JadeRain
# 4           5           {'Format:': ' DVD'}               T. Fisher
# ...       ...                           ...                     ...
# 3012        5           {'Format:': ' DVD'}                    papa
# 3013        5  {'Format:': ' Amazon Video'}                    Nanu
# 3014        5           {'Format:': ' DVD'}         Amazon Customer
# 3015        5  {'Format:': ' Amazon Video'}         Kindle Customer
# 3016        5           {'Format:': ' DVD'}   William E. Bondar Jr.
#
#                                              reviewText  \
# 0     So sorry I didn't purchase this years ago when...
# ...
